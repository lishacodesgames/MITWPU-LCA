# %%
# Assignment 3
# Problem: Check whether the traingle is right-angled triangle using function

# Input: 3 sides of a triangle
# Output: Whether triangle is right-angled triangle or not (using function)

import math

def is_right_angled(triangle):
    largest = max(triangle) # hypotenuse
    other_sides = list(triangle)
    other_sides.remove(largest)

    if largest == math.sqrt(other_sides[0]**2 + other_sides[1]**2):
        


    
    side1_is_hyp: bool = (side1 == math.sqrt(side2**2 + side3**2))
    side2_is_hyp: bool = (side3 == math.sqrt(side2**2 + side1**2))
    side3_is_hyp: bool = (side2 == math.sqrt(side1**2 + side3**2))

    if side1_is_hyp or side2_is_hyp or side3_is_hyp:
        return True
    else:
        return False

triangle = (5, 12, 13)
print(is_right_angled(triangle))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 30
#      27     else:
#      28         return False
# ---> 30 print(is_right_angled(5, 4, 3))
#
# TypeError: is_right_angled() takes 1 positional argument but 3 were given
